# %%
import yfinance as yf
import numpy
import pandas as pd

# %%
stockTicker = "F"

autom = yf.Ticker("^QAUTO")
sp500 = yf.Ticker("^GSPC")
stock = yf.Ticker(stockTicker)

#Data of price every minute from 10th of October to 17th of October
dataAutom = autom.history(interval='1m', start='2022-10-10', end='2022-10-17')
dataSp500 = sp500.history(interval='1m', start='2022-10-10', end='2022-10-17')
dataStock = stock.history(interval='1m', start='2022-10-10', end='2022-10-17')

# %%
infoStock = stock.info
display(infoStock.keys())
# Out:
# dict_keys(['zip', 'sector', 'fullTimeEmployees', 'longBusinessSummary', 'city', 'phone', 'state', 'country', 'companyOfficers', 'website', 'maxAge', 'address1', 'fax', 'industry', 'ebitdaMargins', 'profitMargins', 'grossMargins', 'operatingCashflow', 'revenueGrowth', 'operatingMargins', 'ebitda', 'targetLowPrice', 'recommendationKey', 'grossProfits', 'freeCashflow', 'targetMedianPrice', 'currentPrice', 'earningsGrowth', 'currentRatio', 'returnOnAssets', 'numberOfAnalystOpinions', 'targetMeanPrice', 'debtToEquity', 'returnOnEquity', 'targetHighPrice', 'totalCash', 'totalDebt', 'totalRevenue', 'totalCashPerShare', 'financialCurrency', 'revenuePerShare', 'quickRatio', 'recommendationMean', 'exchange', 'shortName', 'longName', 'exchangeTimezoneName', 'exchangeTimezoneShortName', 'isEsgPopulated', 'gmtOffSetMilliseconds', 'quoteType', 'symbol', 'messageBoardId', 'market', 'annualHoldingsTurnover', 'enterpriseToRevenue', 'beta3Year', 'enterpriseToEbitda', '52WeekChange', 'morningStarRiskRa
# ...

# %%
display(infoStock['longName'])
display(infoStock['industry'])
display(infoStock['beta'])
display(infoStock['forwardPE'])
# Out:
# 'Ford Motor Company'
# 'Auto Manufacturers'
# 1.378776
# 6.3994713

# %%
display(dataStock)
lenStock = len(dataStock)
avgPrice = []
for i in range(lenStock):
    avg = (dataStock['High'][i]+dataStock['Low'][i])/2
    avgPrice.append(avg)
avgPriceDf = pd.DataFrame({'avgPrice':avgPrice},index=dataStock.index.values)
display(avgPriceDf)
# Out:
#                               Open     High    Low   Close   Volume  \
# Datetime
# 2022-10-10 09:30:00-04:00  11.5000  11.5000  11.47  11.470  5113450
# 2022-10-10 09:31:00-04:00  11.4900  11.5050  11.41  11.435   965354
# 2022-10-10 09:33:00-04:00  11.2800  11.3000  11.26  11.290  2320359
# 2022-10-10 09:34:00-04:00  11.2950  11.3500  11.25  11.345  1125898
# 2022-10-10 09:35:00-04:00  11.3450  11.3600  11.26  11.285   998564
# ...                            ...      ...    ...     ...      ...
# 2022-10-14 15:55:00-04:00  11.7150  11.7158  11.68  11.680   491344
# 2022-10-14 15:56:00-04:00  11.6850  11.6900  11.68  11.690   285571
# 2022-10-14 15:57:00-04:00  11.6850  11.6900  11.68  11.680   308365
# 2022-10-14 15:58:00-04:00  11.6801  11.6900  11.68  11.690   292943
# 2022-10-14 15:59:00-04:00  11.6900  11.6975  11.68  11.690  1192170
#
#                            Dividends  Stock Splits
# Datetime
# 2022-10-10 09:30:00-04:00          0             0
# ...

# %%
# Out:
#                      avgPrice
# 2022-10-10 13:30:00  11.48500
# 2022-10-10 13:31:00  11.45750
# 2022-10-10 13:33:00  11.28000
# 2022-10-10 13:34:00  11.30000
# 2022-10-10 13:35:00  11.31000
# ...                       ...
# 2022-10-14 19:55:00  11.69790
# 2022-10-14 19:56:00  11.68500
# 2022-10-14 19:57:00  11.68500
# 2022-10-14 19:58:00  11.68500
# 2022-10-14 19:59:00  11.68875
#
# [1944 rows x 1 columns]

# %%
options = stock.option_chain()
calls = options.calls
display(calls)
puts = options.puts
display(puts)
# Out:
#       contractSymbol             lastTradeDate  strike  lastPrice   bid   ask  \
# 0   F221021C00005000 2022-10-17 17:53:56+00:00     5.0       6.85  7.05  7.15
# 1   F221021C00006000 2022-10-17 18:22:32+00:00     6.0       5.75  6.05  6.15
# 2   F221021C00007000 2022-10-17 14:16:25+00:00     7.0       4.81  5.05  5.15
# 3   F221021C00007500 2022-10-07 14:41:10+00:00     7.5       4.70  4.55  4.65
# 4   F221021C00008000 2022-10-17 17:59:12+00:00     8.0       3.80  4.05  4.15
# 5   F221021C00009000 2022-10-18 13:36:10+00:00     9.0       3.25  3.05  3.15
# 6   F221021C00009500 2022-10-17 18:28:29+00:00     9.5       2.00  2.58  2.63
# 7   F221021C00010000 2022-10-18 17:32:44+00:00    10.0       2.08  2.09  2.13
# 8   F221021C00010500 2022-10-18 16:15:16+00:00    10.5       1.57  1.59  1.63
# 9   F221021C00011000 2022-10-18 17:51:35+00:00    11.0       1.11  1.09  1.15
# 10  F221021C00011500 2022-10-18 17:56:39+00:00    11.5       0.68  0.66  0.69
# ...

# %%
calls["strike"][1]
# Out:
# 6.0
